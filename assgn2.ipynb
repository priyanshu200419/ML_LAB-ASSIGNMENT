# %%
import pandas as pd

# %%
pd.read_csv('/AWSales.csv')
# Out:
#        CustomerID  BikeBuyer  AvgMonthSpend
# 0           21173          1          50.97
# 1           13249          1          53.11
# 2           29350          1          54.08
# 3           13503          1          56.93
# 4           22803          1          55.41
# ...           ...        ...            ...
# 18350       25414          0          48.14
# 18351       11459          1          50.23
# 18352       12160          1          49.56
# 18353       14353          0          51.42
# 18354       16676          1          52.27
#
# [18355 rows x 3 columns]

# %%
df = pd.read_csv('/AWSales.csv')

# %%
df.head()
# Out:
#    CustomerID  BikeBuyer  AvgMonthSpend
# 0       21173          1          50.97
# 1       13249          1          53.11
# 2       29350          1          54.08
# 3       13503          1          56.93
# 4       22803          1          55.41

# %%
# first few rows of dataset
print(df.head())
# Out:
#    CustomerID  BikeBuyer  AvgMonthSpend
# 0       21173          1          50.97
# 1       13249          1          53.11
# 2       29350          1          54.08
# 3       13503          1          56.93
# 4       22803          1          55.41

# %%
print("\nColumns in the dataset:")
print(df.columns)
# Out:
# Columns in the dataset:
# Index(['CustomerID', 'BikeBuyer', 'AvgMonthSpend'], dtype='object')

# %%
# selected attributes = BikeBuyer and AvgMonthSpend
daf = df.drop(['CustomerID'],axis =1)

# %%
print(daf.head())
# Out:
#    BikeBuyer  AvgMonthSpend
# 0          1          50.97
# 1          1          53.11
# 2          1          54.08
# 3          1          56.93
# 4          1          55.41

# %%
summary = daf.describe()

# %%
print(summary)
# Out:
#          BikeBuyer  AvgMonthSpend
# count  18355.00000   18355.000000
# mean       0.55173      51.767207
# std        0.49733       3.438024
# min        0.00000      44.100000
# 25%        0.00000      49.410000
# 50%        1.00000      51.420000
# 75%        1.00000      53.600000
# max        1.00000      65.290000

# %%
data_type_summary = {
    "Attribute": ["BikeBuyer", "AvgMonthSpend"],
    "Data Type": ["Discrete, Nominal", "Continuous, Ratio"]
}

summary_df = pd.DataFrame(data_type_summary)
print("\nSummary of Data Types:")
print(summary_df)
# Out:
# Summary of Data Types:
#        Attribute          Data Type
# 0      BikeBuyer  Discrete, Nominal
# 1  AvgMonthSpend  Continuous, Ratio
